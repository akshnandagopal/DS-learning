# %% [markdown]
# Module 4 Case study 3

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#1 Extracting Hurricanes data

h_df = pd.read_csv('1937_m4_datasets_v1_5fa_ae16cor/Hurricanes.csv')
h_df
# Out:
#      Year  Hurricanes
# 0    1914           0
# 1    1915           5
# 2    1916          10
# 3    1917           2
# 4    1918           4
# ..    ...         ...
# 96   2010          12
# 97   2011           7
# 98   2012          10
# 99   2013           2
# 100  2014           6
#
# [101 rows x 2 columns]

# %%
# Year vs no. of hurricanes

plt.bar(h_df['Year'],h_df['Hurricanes'])
plt.xlabel('Year')
plt.ylabel('No. of Hurricanes')
plt.title('No. of hurricanes yearwise analysis')
plt.show()

# %%
#2 Extracting CityTemps data

ct_df = pd.read_csv('1937_m4_datasets_v1_5fa_ae16cor/CityTemps.csv')
ct_df
# Out:
#     Year  Month  Moscow  Melbourne  San Francisco
# 0   2014      1    -8.6       22.0           12.8
# 1   2014      2    -1.9       21.5           12.7
# 2   2014      3     2.8       19.5           15.0
# 3   2014      4     7.0       15.8           15.7
# 4   2014      5    16.0       13.9           17.5
# 5   2014      6    16.1       11.3           17.9
# 6   2014      7    21.1        9.9           19.4
# 7   2014      8    19.2       10.4           19.5
# 8   2014      9    12.3       12.8           20.2
# 9   2014     10     3.7       15.6           20.4
# 10  2014     11    -1.3       17.3           15.4
# 11  2014     12    -3.9       18.9           13.8
# 12  2015      1    -4.4       20.4           12.2
# 13  2015      2    -2.2       21.8           14.8
# 14  2015      3     2.0       17.4           15.7
# 15  2015      4     6.1       14.1           14.8
# 16  2015      5    14.2       12.6           14.7
# 17  2015      6    17.9        9.8           17.1
# ...

# %%
ct_df['Year'].value_counts()
# Out:
# Year
# 2014    12
# 2015    12
# Name: count, dtype: int64

# %%
# Temperatures by city histogram

plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.hist(ct_df['San Francisco'], bins=10, color='green', edgecolor='yellow')
plt.xlabel('Temperature')
plt.ylabel('Frequency')
plt.title('San Francisco')

plt.subplot(1,2,2)
plt.hist(ct_df['Moscow'], bins=10,color='blue', edgecolor='yellow')
plt.xlabel('Temperature')
plt.ylabel('Frequency')
plt.title('Moscow')

# view histogram
plt.tight_layout()
plt.show()

# %%
#3 create a csv file and read the file

# reading data from existing file
data = pd.read_csv('1937_m4_datasets_v1_5fa_ae16cor/Cars2015.csv')

# create a file with the dataframe data
csv_data = data.to_csv('New File.csv')

# reading the created new file into pandas df
read_df = pd.read_csv('New File.csv')
read_df # verifying if the file was created and reads successfully
# Out:
#      Unnamed: 0        Make       Model       Type  LowPrice  HighPrice Drive  \
# 0             0   Chevrolet       Spark  Hatchback    12.270     25.560   FWD
# 1             1     Hyundai      Accent  Hatchback    14.745     17.495   FWD
# 2             2         Kia         Rio      Sedan    13.990     18.290   FWD
# 3             3  Mitsubishi      Mirage  Hatchback    12.995     15.395   FWD
# 4             4      Nissan  Versa Note  Hatchback    14.180     17.960   FWD
# ..          ...         ...         ...        ...       ...        ...   ...
# 105         105      Toyoto     Sequioa      7Pass    44.395     64.320   RWD
# 106         106      Nissan  Pathfinder      7Pass    29.510     43.100   FWD
# 107         107       Acura         MDX      7Pass    42.865     57.080   FWD
# 108         108     Hyundai    Santa Fe      7Pass    30.150     36.000   FWD
# 109         109        GMC        Yukon      7Pass    47.740     67.520   RWD
#
# ...

# %%
#4  simple plot 
# X = [1,2,3,4] y = [20, 21, 20.5, 20.8]

X = [1,2,3,4]
y = [20, 21, 20.5, 20.8]

plt.plot(X,y)
plt.show()

# %%
#5

plt.plot(X,y, linestyle='--', marker='o', color='b')
plt.show()

# %%
print(min(X),max(X),min(y),max(y))
# Out:
# 1 4 20 21

# %%
# axis configuration and titles,labels, error bar, figsize, dpi

y_error = [0.12, 0.13, 0.2, 0.1]

plt.figure(figsize=(4,5),dpi=100)
plt.errorbar(X, y, yerr=y_error, linestyle='--', marker='o', color='b')
plt.axis([min(X),max(X),min(y),max(y)])
plt.title('Simple Plot',fontsize=14)
plt.xlabel('X Axis',fontsize=14)
plt.ylabel('Y Axis',fontsize=14)
plt.show()

# %%
# scatter plot of x and y 

X = np.random.rand(50)
y = np.random.rand(50)

plt.figure(figsize=(5, 5))
plt.scatter(X, y)
plt.title('Scatter Plot of Random Values')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()

# %%
# create a dataframe

data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'], 
'female': [0, 1, 1, 0, 1],'age': [42, 52, 36, 24, 73],
'preTestScore': [4, 24, 31, 2, 3],
'postTestScore': [25, 94, 57, 62, 70]
}

df = pd.DataFrame(data)
df
# Out:
#   first_name last_name  female  age  preTestScore  postTestScore
# 0      Jason    Miller       0   42             4             25
# 1      Molly  Jacobson       1   52            24             94
# 2       Tina       Ali       1   36            31             57
# 3       Jake    Milner       0   24             2             62
# 4        Amy     Cooze       1   73             3             70

# %%
# scatter plot of pretestscore and posttestscore

plt.scatter(df['preTestScore'],df['postTestScore'],s=df['age'])
plt.xlabel('preTestScore')
plt.ylabel('postTestScore')
plt.title('Scatter plot of preTestScore and postTestScore')
plt.show()

# %%
# scatter plot with color

plt.scatter(df['preTestScore'],df['postTestScore'],s=300, c=df['female'], cmap='bwr',alpha=0.6)
plt.xlabel('preTestScore')
plt.ylabel('postTestScore')
plt.title('Scatter plot of preTestScore and postTestScore')
plt.colorbar(label='Gender (0: Male, 1: Female)')
plt.show()
